# %%
__author__ = 'Cyrille Mvomo, https://github.com/cyrillemvomo'
__version__ = "1"
__license__ = "MIT"

# %% [markdown]
# **Import**

# %%
import sys
sys.path.append("/Users/cyrilleetude/Documents/GitHub/WhiteBoxDL/Preprocessing/1_Get_Data/McGill_Cohort/1_Extract")
from Extracted_Fatigue import Extracted_Data_Fatigue
import numpy as np
import pandas as pd
import copy #so that I can copy object
import pickle
import os

# %% [markdown]
# **Read**

# %%
EXTRACTED_DATA = Extracted_Data_Fatigue(Gait_Data_Path = "/Volumes/Active/Datasets/A_Principal_Component_Model_Provides_Gait_Features_for_Tracking_Symptoms_Severity_and_Neural_Progres/McGill_Cohort_2_just_wearables/Wearables/Steering", 
                                Medical_Record_Path = "/Volumes/Active/Datasets/WhiteBoxDL/Demographics/McGill_Fatigue/Demographic", 
                                Source_Folder_Path = "/Users/cyrilleetude/Documents/GitHub/WhiteBoxDL/Preprocessing/1_Get_Data/McGill_Cohort/0_Source").RawData_Extracted(save_data=False)

# %% [markdown]
# **Crop into 5 second bouts**

# %%
def Crop(ID, medicalrecord_df, df_steering, to_crop_steering_start = []):
    '''
    Function to crop the signal
        input:
        - ID : string representing the Participant ID
        - medicalrecord_df : df containing medical record info
        - df_steering : data frame containing acceleration signal in steering condition
        - to_crop_steering_start : list of 2 integers corresponding frames to crop in the first 2 min of gait (steering condition) (default = [])

        output: a dict with 1 dfs
            - cropped_steering_start : df containing the cropped signal
    '''
    # Declare
    sampling_rate= 128 #hz used to convert in frames
    gait_start_steering = (medicalrecord_df.loc[medicalrecord_df.index == ID]["Start APDM steering"].values[0] + 30) #apdm s when gait task start + 30 seconds (start effects)

    # Crop
        # Steering
    if len(to_crop_steering_start) == 0: # if no specified comments marked
        to_crop_steering_start = [gait_start_steering*sampling_rate, (gait_start_steering+120)*sampling_rate] # crop at frame start + 30 s (start effect) and frame 2 min later
    else:
        to_crop_steering_start = to_crop_steering_start #specified frames

    return {
            "cropped_steering_start" : df_steering.iloc[to_crop_steering_start[0]:to_crop_steering_start[1], :2].reset_index(drop=True)
            }

# %%
id = "PD" + "61"
Cropped = Crop(ID = id, 
          medicalrecord_df = EXTRACTED_DATA["Medical_Record"], 
          df_steering = EXTRACTED_DATA[id], 
          to_crop_steering_start = [] )

# Save as excel file based on comments
Cropped["cropped_steering_start"].to_csv(f"/Users/cyrilleetude/Documents/GitHub/WhiteBoxDL/Preprocessing/1_Get_Data/McGill_Cohort/2_Transform/temp/pre_cropped_fatigue/{id}.csv", index = False)

# %%
id = "PD" + "94"
Cropped = Crop(ID = id, 
          medicalrecord_df = EXTRACTED_DATA["Medical_Record"], 
          df_steering = EXTRACTED_DATA[id], 
          to_crop_steering_start = [] )

# Save as excel file based on comments
Cropped["cropped_steering_start"].to_csv(f"/Users/cyrilleetude/Documents/GitHub/WhiteBoxDL/Preprocessing/1_Get_Data/McGill_Cohort/2_Transform/temp/pre_cropped_fatigue/{id}.csv", index = False)

# %%
id = "PD" + "80"
Cropped = Crop(ID = id, 
          medicalrecord_df = EXTRACTED_DATA["Medical_Record"], 
          df_steering = EXTRACTED_DATA[id], 
          to_crop_steering_start = [] )

# Save as excel file based on comments
Cropped["cropped_steering_start"].to_csv(f"/Users/cyrilleetude/Documents/GitHub/WhiteBoxDL/Preprocessing/1_Get_Data/McGill_Cohort/2_Transform/temp/pre_cropped_fatigue/{id}.csv", index = False)

# %%
id = "PD" + "81"

Cropped = Crop(ID = id, 
          medicalrecord_df = EXTRACTED_DATA["Medical_Record"], 
          df_steering = EXTRACTED_DATA[id], 
          to_crop_steering_start = [128*1150, 128*1180] )

# Save as excel file based on comments
Cropped["cropped_steering_start"].to_csv(f"/Users/cyrilleetude/Documents/GitHub/WhiteBoxDL/Preprocessing/1_Get_Data/McGill_Cohort/2_Transform/temp/pre_cropped_fatigue/{id}.csv", index = False)

# %%
id = "PD" + "83"

Cropped = Crop(ID = id, 
          medicalrecord_df = EXTRACTED_DATA["Medical_Record"], 
          df_steering = EXTRACTED_DATA[id], 
          to_crop_steering_start = [128*1210, 128*1240] )

# Save as excel file based on comments
Cropped["cropped_steering_start"].to_csv(f"/Users/cyrilleetude/Documents/GitHub/WhiteBoxDL/Preprocessing/1_Get_Data/McGill_Cohort/2_Transform/temp/pre_cropped_fatigue/{id}.csv", index = False)

# %%
id = "PD" + "84"
Cropped = Crop(ID = id, 
          medicalrecord_df = EXTRACTED_DATA["Medical_Record"], 
          df_steering = EXTRACTED_DATA[id], 
          to_crop_steering_start = [] )

# Save as excel file based on comments
Cropped["cropped_steering_start"].to_csv(f"/Users/cyrilleetude/Documents/GitHub/WhiteBoxDL/Preprocessing/1_Get_Data/McGill_Cohort/2_Transform/temp/pre_cropped_fatigue/{id}.csv", index = False)

# %%
id = "PD" + "85"
Cropped = Crop(ID = id, 
          medicalrecord_df = EXTRACTED_DATA["Medical_Record"], 
          df_steering = EXTRACTED_DATA[id], 
          to_crop_steering_start = [] )

# Save as excel file based on comments
Cropped["cropped_steering_start"].to_csv(f"/Users/cyrilleetude/Documents/GitHub/WhiteBoxDL/Preprocessing/1_Get_Data/McGill_Cohort/2_Transform/temp/pre_cropped_fatigue/{id}.csv", index = False)

# %%
id = "PD" + "87"
Cropped = Crop(ID = id, 
          medicalrecord_df = EXTRACTED_DATA["Medical_Record"], 
          df_steering = EXTRACTED_DATA[id], 
          to_crop_steering_start = [] )

# Save as excel file based on comments
Cropped["cropped_steering_start"].to_csv(f"/Users/cyrilleetude/Documents/GitHub/WhiteBoxDL/Preprocessing/1_Get_Data/McGill_Cohort/2_Transform/temp/pre_cropped_fatigue/{id}.csv", index = False)

# %%
id = "PD" + "91"
Cropped = Crop(ID = id, 
          medicalrecord_df = EXTRACTED_DATA["Medical_Record"], 
          df_steering = EXTRACTED_DATA[id], 
          to_crop_steering_start = [] )

# Save as excel file based on comments
Cropped["cropped_steering_start"].to_csv(f"/Users/cyrilleetude/Documents/GitHub/WhiteBoxDL/Preprocessing/1_Get_Data/McGill_Cohort/2_Transform/temp/pre_cropped_fatigue/{id}.csv", index = False)

# %%
id = "PD" + "95"
Cropped = Crop(ID = id, 
          medicalrecord_df = EXTRACTED_DATA["Medical_Record"], 
          df_steering = EXTRACTED_DATA[id], 
          to_crop_steering_start = [] )

# Save as excel file based on comments
Cropped["cropped_steering_start"].to_csv(f"/Users/cyrilleetude/Documents/GitHub/WhiteBoxDL/Preprocessing/1_Get_Data/McGill_Cohort/2_Transform/temp/pre_cropped_fatigue/{id}.csv", index = False)

# %%
# create a cropped dict
    # Read
datas_cropped = os.listdir("/Users/cyrilleetude/Documents/GitHub/WhiteBoxDL/Preprocessing/1_Get_Data/McGill_Cohort/2_Transform/temp/pre_cropped_fatigue")
datas_cropped = [i[:-4] for i in datas_cropped]
    #Create Dict
EXTRACTED_DATA_CROPPED = {}
for participant_id in datas_cropped:
    EXTRACTED_DATA_CROPPED[participant_id] = pd.read_csv(f"/Users/cyrilleetude/Documents/GitHub/WhiteBoxDL/Preprocessing/1_Get_Data/McGill_Cohort/2_Transform/temp/pre_cropped_fatigue/{participant_id}.csv")

# %%
EXTRACTED_DATA_CROPPED.keys()
# Out:
# dict_keys(['PD61', 'PD85', 'PD91', 'PD84', 'PD87', 'PD83', 'PD80', 'PD94', 'PD95', 'PD81'])

# %%
# Split in 5 second bouts
EXTRACTED_DATA_SPLITTED = {}
sampling_rate=128
for participant_id in list(EXTRACTED_DATA_CROPPED.keys()):
    five_s_bouts_indexes = np.array_split(EXTRACTED_DATA_CROPPED[participant_id].index.values, len(EXTRACTED_DATA_CROPPED[participant_id])//(5*sampling_rate))
    participant_data = []
    for bout_id in range(len(five_s_bouts_indexes)):
        participant_data.append(EXTRACTED_DATA_CROPPED[participant_id].iloc[five_s_bouts_indexes[bout_id]].ACC_VERTICAL_MS2.values)
    
    EXTRACTED_DATA_SPLITTED[participant_id] = participant_data

# %%
# Save as bin file 
with open("/Users/cyrilleetude/Documents/GitHub/WhiteBoxDL/Preprocessing/1_Get_Data/McGill_Cohort/2_Transform/temp/Extracted_Data_Fatigue.bin", "wb") as f:
            pickle.dump(EXTRACTED_DATA_SPLITTED, f)
